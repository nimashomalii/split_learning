# %%
# !git clone https://github.com/nimashomalii/split_learning.git
# %cd split_learning
import importlib
import torch
import dataset
importlib.reload(dataset)
import pandas as pd
from dataset import data_preparing

import client_transmitter


from client_transmitter import Transmitter
# Out:
# Cloning into 'split_learning'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 31 (delta 9), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (31/31), 11.58 KiB | 3.86 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/split_learning/split_learning/split_learning/split_learning/split_learning/split_learning/split_learning/split_learning/split_learning/split_learning/split_learning/split_learning

# %%
chartevents_path = "/content/drive/MyDrive/split_learning/CHARTEVENTS.csv"
df_chartevents = pd.read_csv(chartevents_path)
data = data_preparing(df_chartevents , 'metavision' , 3 , 0.2 )
server_url = " https://24d96878f521.ngrok-free.app/echo_lists"
client_send = Transmitter(server_url)

for d , l in data.load_train(batch_size = 12) :
  #print(d)
  #print(l)
  print(client_send.send_data(d, l))
# Out:
# /tmp/ipython-input-398252398.py:2: DtypeWarning: Columns (8,10,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_chartevents = pd.read_csv(chartevents_path)
# ...
